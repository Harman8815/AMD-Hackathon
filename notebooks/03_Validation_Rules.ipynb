# %%
# 📦 Dependency Installation (for Colab or local environments)
try:
    import pandas as pd
    print("✅ Standard dependencies found.")
except ImportError:
    print("🚀 Installing missing dependencies...")
    # !pip install -q pandas
    print("✅ Installation complete.")

# %% [markdown]
# # ⚖️ Validation & Rules
# ### *Automated Compliance Checking*
#
# This notebook focuses on validating design parameters against the structured `rules.json` file.

# %%
import json
import pandas as pd

RULES_PATH = "../data/rules.json"

with open(RULES_PATH, "r") as f:
    rules = json.load(f)

df_rules = pd.DataFrame(rules)
print(f"Loaded {len(df_rules)} rules.")
df_rules.head()
